# %% [markdown]
# ### 10-10-2019
# ### Pandas

# %%
import numpy as ns

# %%
ns.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
import pandas as pa

# %%
pa.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pa.Series(["alekhya","gireesha"])
# Out:
# 0     alekhya
# 1    gireesha
# dtype: object

# %%
pa.Series(pa.date_range('10-10-2019','10-13-2019'))      # format in pandasbe in mm-dd-yy
# Out:
# 0   2019-10-10
# 1   2019-10-11
# 2   2019-10-12
# 3   2019-10-13
# dtype: datetime64[ns]

# %%
pa.Series(pa.date_range(start='10-10-2019',end='10-13-2019',freq='6H'))
# Out:
# 0    2019-10-10 00:00:00
# 1    2019-10-10 06:00:00
# 2    2019-10-10 12:00:00
# 3    2019-10-10 18:00:00
# 4    2019-10-11 00:00:00
# 5    2019-10-11 06:00:00
# 6    2019-10-11 12:00:00
# 7    2019-10-11 18:00:00
# 8    2019-10-12 00:00:00
# 9    2019-10-12 06:00:00
# 10   2019-10-12 12:00:00
# 11   2019-10-12 18:00:00
# 12   2019-10-13 00:00:00
# dtype: datetime64[ns]

# %%
help(pa.date_range)
# Out:
# Help on function date_range in module pandas.core.indexes.datetimes:
#
# date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize=False, name=None, closed=None, **kwargs)
#     Return a fixed frequency DatetimeIndex.
#
#     Parameters
#     ----------
#     start : str or datetime-like, optional
#         Left bound for generating dates.
#     end : str or datetime-like, optional
#         Right bound for generating dates.
#     periods : integer, optional
#         Number of periods to generate.
#     freq : str or DateOffset, default 'D'
#         Frequency strings can have multiples, e.g. '5H'. See
#         :ref:`here <timeseries.offset_aliases>` for a list of
#         frequency aliases.
#     tz : str or tzinfo, optional
#         Time zone name for returning localized DatetimeIndex, for example
#         'Asia/Hong_Kong'. By default, the resulting DatetimeIndex is
#         timezone-naive.
#     normalize : bool, default False
# ...

# %%
pa.Series([85,96,74,65],index=["a","b","c","d"])
# Out:
# a    85
# b    96
# c    74
# d    65
# dtype: int64

# %% [markdown]
# ### DataFrame Creation

# %%
pa.DataFrame([[1,2,3],["a","s","t"],[45,32,12]])                 # no of series is called a data frame
# Out:
#     0   1   2
# 0   1   2   3
# 1   a   s   t
# 2  45  32  12

# %%
pa.DataFrame({"rollno":[98,99,100],"name":["p","kp","m"],"marks":[99,98,97]})
# Out:
#    rollno name  marks
# 0      98    p     99
# 1      99   kp     98
# 2     100    m     97

# %%
p=pa.read_csv("income.csv")
p
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
p.shape
# Out:
# (5, 11)

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
# GEOID    5 non-null object
# State    5 non-null object
# 2005     5 non-null int64
# 2006     5 non-null int64
# 2007     5 non-null int64
# 2008     5 non-null int64
# 2009     5 non-null int64
# 2010     5 non-null int64
# 2011     5 non-null int64
# 2012     5 non-null int64
# 2013     5 non-null int64
# dtypes: int64(9), object(2)
# memory usage: 520.0+ bytes

# %%
p.columns
# Out:
# Index(['GEOID', 'State', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013'],
#       dtype='object')

# %%
p.values
# Out:
# array([['04000US01', 'Alabama', 37150, 37952, 42212, 44476, 39980, 40933,
#         42590, 43464, 41381],
#        ['04000US02', 'Alaska', 55891, 56418, 62993, 63989, 61604, 57848,
#         57431, 63648, 61137],
#        ['04000US04', 'Arizona', 45245, 46657, 62993, 46914, 45739, 46896,
#         48621, 47044, 50602],
#        ['04000US05', 'Arkansas', 36658, 37057, 40795, 39586, 36538,
#         38587, 41302, 39018, 39919],
#        ['04000US06', 'California', 51755, 55319, 55734, 57014, 56134,
#         54283, 53367, 57020, 57528]], dtype=object)

# %%
p
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
p['State']
# Out:
# 0       Alabama
# 1        Alaska
# 2       Arizona
# 3      Arkansas
# 4    California
# Name: State, dtype: object

# %%
p['2009']
# Out:
# 0    39980
# 1    61604
# 2    45739
# 3    36538
# 4    56134
# Name: 2009, dtype: int64

# %%
p[1::]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
p[3:4:1]
# Out:
#        GEOID     State   2005   2006   2007   2008   2009   2010   2011  \
# 3  04000US05  Arkansas  36658  37057  40795  39586  36538  38587  41302
#
#     2012   2013
# 3  39018  39919

# %%
p[2:4:1]
# Out:
#        GEOID     State   2005   2006   2007   2008   2009   2010   2011  \
# 2  04000US04   Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05  Arkansas  36658  37057  40795  39586  36538  38587  41302
#
#     2012   2013
# 2  47044  50602
# 3  39018  39919

# %%
p[2:3:1]
# Out:
#        GEOID    State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 2  04000US04  Arizona  45245  46657  62993  46914  45739  46896  48621  47044
#
#     2013
# 2  50602

# %%
p.sort_index(axis=0,ascending=False)
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
#
#     2012   2013
# 4  57020  57528
# 3  39018  39919
# 2  47044  50602
# 1  63648  61137
# 0  43464  41381

# %%
p.sort_values(by="State",ascending=True)                #print according to alphabetical order
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
p.set_index('State',inplace=True)

# %%
p
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  62993  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013
# State
# Alabama     41381
# Alaska      61137
# Arizona     50602
# Arkansas    39919
# California  57528

# %%
pa.read_csv("income.csv")
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %% [markdown]
# ### For data manipulation we have two types
# * iloc(base or index)
# * loc(based on column)

# %%
p.iloc[2]
# Out:
# GEOID    04000US04
# 2005         45245
# 2006         46657
# 2007         62993
# 2008         46914
# 2009         45739
# 2010         46896
# 2011         48621
# 2012         47044
# 2013         50602
# Name: Arizona, dtype: object

# %%
def fun(st):
    for i in st:
        if i!='z':
            print(chr(ord(i)+1),end="")
        else:
            print(chr(ord(i)))
fun("hello")
# Out:
# ifmmp
